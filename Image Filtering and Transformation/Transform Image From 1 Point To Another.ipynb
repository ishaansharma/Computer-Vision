# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 

# %matplotlib inline 


def _plot_cv_img(input_image):     
    """     
    Converts an image from BGR to RGB and plots     
    """   
    # change color channels order for matplotlib     
    plt.imshow(cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB))          

    # For easier view, turn off axis around image     
    plt.axis('off')
    plt.show()
    

def main():
    # read an image 
    img = cv2.imread('pics/monalisa.jpg')
    
    # create transformation matrix form preselected points
    pts1 = np.float32([[40,40],[200,0],[40,200]])
    pts2 = np.float32([[10,100],[200,40],[100,250]])
    affine_tr = cv2.getAffineTransform(pts1,pts2)

    transformed = cv2.warpAffine(img, affine_tr, (img.shape[1]*2,img.shape[0]*2))

    # Do plot
    _plot_cv_img(transformed)

if __name__ == '__main__':
    main()
